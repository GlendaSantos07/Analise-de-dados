# %% [markdown]
# Glenda dos Santos Silva
# RA - 3019202917

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
caminho = '/content/drive/MyDrive/InteligenciaArtificial'

# %%
for f in os.listdir(caminho):
  print(f)
# Out:
# reclamacoes-fundamentadas-sindec-2012.csv
# reclamacoes-fundamentadas-sindec-2013.csv
# reclamacoes-fundamentadas-sindec-2014.csv
# reclamacoes-fundamentadas-sindec-2015.csv
# reclamacoes-fundamentadas-sindec-2016.csv

# %%
files = []

for f in os.listdir(caminho):
  if f != 'teste.csv':
    files.append(f)

# %%
for f in files:
  print(caminho + '/' + f )
# Out:
# /content/drive/MyDrive/InteligenciaArtificial/reclamacoes-fundamentadas-sindec-2012.csv
# /content/drive/MyDrive/InteligenciaArtificial/reclamacoes-fundamentadas-sindec-2013.csv
# /content/drive/MyDrive/InteligenciaArtificial/reclamacoes-fundamentadas-sindec-2014.csv
# /content/drive/MyDrive/InteligenciaArtificial/reclamacoes-fundamentadas-sindec-2015.csv
# /content/drive/MyDrive/InteligenciaArtificial/reclamacoes-fundamentadas-sindec-2016.csv

# %%
df = pd.DataFrame()

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
for f in files:
  frames = pd.read_csv(caminho + "/" + f)
  df = df.append(frames, ignore_index=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (22) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#          AnoCalendario         DataArquivamento             DataAbertura  \
# 0                 2012  2012-07-13 17:44:45.000  2009-09-17 10:48:42.000
# 1                 2012  2012-07-13 17:37:19.000  2009-09-17 10:02:24.000
# 2                 2012  2012-07-16 09:07:13.000  2009-09-17 11:36:47.000
# 3                 2012  2012-12-10 09:05:09.000  2009-09-21 09:01:49.000
# 4                 2012  2012-07-13 17:51:01.000  2009-09-18 17:32:22.000
# ...                ...                      ...                      ...
# 1206067           2016  2016-08-24 10:19:29.000  2016-05-06 11:21:45.000
# 1206068           2016  2016-10-27 09:19:09.000  2016-05-02 15:28:57.000
# 1206069           2016  2016-09-21 09:11:21.000  2016-04-29 16:20:30.000
# 1206070           2016  2016-08-16 10:58:52.000  2016-04-19 07:58:16.000
# 1206071           2016  2016-09-21 09:44:57.000  2016-04-19 08:42:27.000
#
#          CodigoRegiao        Regiao  UF  \
# 0                   3       Sudeste  ES
# 1                   3       Sudeste  ES
# 2                   3       Sudeste  ES
# 3                   5  Centro-oeste  GO
# 4                   3       Sudeste  ES
# ...               ...           ...  ..
# 1206067             3       Sudeste  SP
# 1206068             3       Sudeste  SP
# 1206069             3       Sudeste  SP
# 1206070             3       Sudeste  SP
# 1206071             3       Sudeste  SP
#
#                                             strRazaoSocial  \
# 0                            IBI PROMOTORA DE VENDAS LTDA.
# 1                      SAMSUNG ELETRONICA DA AMAZONIA LTDA
# 2                                LINNU''S AUTOMOVEIS LTDA.
# 3        AMAZON PC INDUSTRIA E COMERCIO DE MICROCOMPUTA...
# 4                           OFFICINA REVESTIMENTOS LTDA ME
# ...                                                    ...
# 1206067                                       OI MÓVEL S/A
# 1206068  ELETROPAULO METROPOLITANA ELETRICIDADE DE S PAULO
# 1206069                   AUTO ESCOLA ULTRA FACIL LTDA EPP
# 1206070  FINANCEIRA ITAU CBD S/A CRÉDITO FINANCIAMENTO ...
# 1206071                   VALBET CENTRO AUTOMOTIVO LTDA ME
#
#                        strNomeFantasia  Tipo    NumeroCNPJ  ...  \
# 0                             IBI CARD     1  7.448120e+13  ...
# 1                              SAMSUNG     1  2.802730e+11  ...
# 2                    LINNUS AUTOMOVEIS     1  3.635548e+13  ...
# 3                            AMAZON PC     1  1.614079e+12  ...
# 4                                  NaN     1  5.444155e+12  ...
# ...                                ...   ...           ...  ...
# 1206067               OI CELULAR/OI TV     1  5.423963e+12  ...
# 1206068      ELETROPAULO METROPOLITANA     1  6.169523e+13  ...
# 1206069                            NaN     1  1.802559e+13  ...
# 1206070  FIC FINANCEIRA ITAÚ CBD / FIT     1  6.881898e+12  ...
# 1206071                            NaN     1  2.035944e+13  ...
#
#          CNAEPrincipal                                  DescCNAEPrincipal  \
# 0            7490104.0  ATIVIDADES DE INTERMEDIAÇÃO E AGENCIAMENTO DE ...
# 1            2640000.0  FABRICAÇÃO DE APARELHOS DE RECEPÇÃO, REPRODUÇÃ...
# 2            4512902.0   COMÉRCIO SOB CONSIGNAÇÃO DE VEÍCULOS AUTOMOTORES
# 3            2621300.0          FABRICAÇÃO DE EQUIPAMENTOS DE INFORMÁTICA
# 4            4744005.0  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# ...                ...                                                ...
# 1206067      6120501.0                            TELEFONIA MÓVEL CELULAR
# 1206068      3514000.0                   DISTRIBUIÇÃO DE ENERGIA ELÉTRICA
# 1206069      8599601.0                             FORMAÇÃO DE CONDUTORES
# 1206070      6436100.0  SOCIEDADES DE CRÉDITO, FINANCIAMENTO E INVESTI...
# 1206071            NaN                                                NaN
#
#         Atendida  CodigoAssunto  \
# 0              N             54
# 1              N            101
# 2              N            129
# 3              S            102
# 4              N            118
# ...          ...            ...
# 1206067        S            187
# 1206068        N            185
# 1206069        S            264
# 1206070        S             53
# 1206071        S            250
#
#                                           DescricaoAssunto CodigoProblema  \
# 0                                        Cartão de Crédito           32.0
# 1        Telefone ( Convencional, Celular, Interfone, E...          102.0
# 2                        Carro Nacional Zero ( Montadora )          111.0
# 3                Microcomputador / Produtos de Informática          102.0
# 4        Material de Acabamento de Construção Pronto (P...          116.0
# ...                                                    ...            ...
# 1206067                                  Telefonia Celular          143.0
# 1206068                                   Energia Elétrica          134.0
# 1206069  Automóvel - Locação / Assistência Automobilíst...          185.0
# 1206070                                    Banco comercial           28.0
# 1206071  Oficinas ( Mecânica, Funilaria, Auto-Elétrica,...          183.0
#
#                                          DescricaoProblema SexoConsumidor  \
# 0                           Calculo de prestação em atraso              F
# 1                  Garantia (Abrangência, cobertura, etc.)              M
# 2                                           Venda enganosa              M
# 3                  Garantia (Abrangência, cobertura, etc.)              M
# 4        Contrato/pedido/orçamento (rescisão, descumpri...              M
# ...                                                    ...            ...
# 1206067           Contrato - Rescisão/alteração unilateral              M
# 1206068                          Cobrança indevida/abusiva              M
# 1206069        Serviço não concluído /Fornecimento parcial              F
# 1206070                          Cobrança indevida/abusiva              F
# 1206071  Vicio de qualidade (mal executado, inadequado,...              M
#
#          FaixaEtariaConsumidor CEPConsumidor
# 0              mais de 70 anos      29072040
# 1           entre 31 a 40 anos      29115360
# 2           entre 21 a 30 anos      29060110
# 3           entre 21 a 30 anos      75911000
# 4                Nao Informada      29090120
# ...                        ...           ...
# 1206067     entre 51 a 60 anos     4763310.0
# 1206068     entre 41 a 50 anos     4846010.0
# 1206069     entre 21 a 30 anos     5731090.0
# 1206070     entre 21 a 30 anos     4438250.0
# 1206071     entre 51 a 60 anos     4470261.0
#
# [1206072 rows x 23 columns]

# %% [markdown]
# **Porcentagem de reclamações por ano**

# %%
plt.style.use("ggplot")

df['AnoCalendario'].value_counts().plot(kind='pie',autopct='%1.1f%%' ,label="Ocorrências por ano" ,figsize=(8, 8))
plt.show()
